# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Download required data
nltk.download('stopwords')

# Input text
text = "The students are studying different subjects in the university."

# Convert text into words
words = text.lower().split()

# Stop words
stop_words = set(stopwords.words('english'))

# Remove stop words
filtered_words = [word for word in words if word not in stop_words]

# Create stemmer
stemmer = PorterStemmer()

# Apply stemming
stemmed_words = [stemmer.stem(word) for word in filtered_words]

print("Original Text:")
print(text)

print("\nAfter Stop Word Removal:")
print(filtered_words)

print("\nAfter Stemming:")
print(stemmed_words)
# Out:
# Original Text:
# The students are studying different subjects in the university.
#
# After Stop Word Removal:
# ['students', 'studying', 'different', 'subjects', 'university.']
#
# After Stemming:
# ['student', 'studi', 'differ', 'subject', 'university.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Download required data
nltk.download('stopwords')

# Input text
text = "The students are studying different subjects in the university."

# Convert text into words
words = text.lower().split()

# Stop words
stop_words = set(stopwords.words('english'))

# Remove stop words
filtered_words = [word for word in words if word not in stop_words]

# Create stemmer
stemmer = PorterStemmer()

# Apply stemming
stemmed_words = [stemmer.stem(word) for word in filtered_words]

print("Original Text:")
print(text)

print("\nAfter Stop Word Removal:")
print(filtered_words)

print("\nAfter Stemming:")
print(stemmed_words)
# Out:
# Original Text:
# The students are studying different subjects in the university.
#
# After Stop Word Removal:
# ['students', 'studying', 'different', 'subjects', 'university.']
#
# After Stemming:
# ['student', 'studi', 'differ', 'subject', 'university.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
